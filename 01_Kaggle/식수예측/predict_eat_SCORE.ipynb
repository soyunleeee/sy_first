# %%
# !pip install catboost
# !pip install pycaret

# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import datetime as dt
from pycaret.regression import *
import matplotlib.pyplot as plt
import seaborn as sns
import catboost

import matplotlib.font_manager as fm
import matplotlib as mpl

warnings.filterwarnings(action='ignore')

plt.rcParams['font.family'] = 'Malgun Gothic'
mpl.rcParams["figure.figsize"] = (8,4)
mpl.rcParams['axes.grid'] = True

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
train.shape, test.shape
# Out:
# ((1205, 12), (50, 10))

# %%
train.head()
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
# 2  2016-02-03  수   2601      56     180             111          0.0
# 3  2016-02-04  목   2601     104     220             355          0.0
# 4  2016-02-05  금   2601     278     181              34          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
# 2  모닝롤/베이글  우유/두유/주스 계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 콩나물국...
# 3  모닝롤/토마토샌드  우유/두유/주스 계란후라이  닭죽/쌀밥 (쌀,닭:국내산) 근대국...
# 4  모닝롤/와플  우유/두유/주스 계란후라이  쇠고기죽/쌀밥 (쌀:국내산) 재첩국  방...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
# 2  카레덮밥 (쌀,현미흑미:국내산) 팽이장국  치킨핑거 (닭고기:국내산) 쫄면야채무침 ...
# 3  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 쇠고기무국  주꾸미볶음  부추전  시금치나물  ...
# 4  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 떡국  돈육씨앗강정 (돼지고기:국내산) 우엉잡채...
#
#                                                 석식메뉴     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0
# 2  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 청국장찌개  황태양념구이 (황태:러시아산) 고기...  1017.0  573.0
# 3  미니김밥*겨자장 (쌀,현미흑미:국내산) 우동  멕시칸샐러드  군고구마  무피클  포...   978.0  525.0
# 4  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 차돌박이찌개 (쇠고기:호주산) 닭갈비 (닭고기:...   925.0  330.0

# %%
train=train[train['일자']>='2020-03-22']
train2=train.set_index('일자')
train2=train.reset_index()
train2= train2.drop('index', axis=1)

train2.head()
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2020-03-23  월   2950     109     178             687        285.0
# 1  2020-03-24  화   2950     131     137             639        303.0
# 2  2020-03-25  수   2950     122     146               1        303.0
# 3  2020-03-26  목   2950     133     133             584        288.0
# 4  2020-03-27  금   2950     254     156               0        260.0
#
#                                                 조식메뉴  \
# 0  모닝롤/베이글  우유/주스 계란후라이 누룽지탕/쌀밥 (쌀:국내산) 감자국  꽈리고추...
# 1  모닝롤/햄치즈샌드  우유/주스 계란후라이 잣죽/쌀밥 (쌀:국내산) 쑥국  수제어묵볶...
# 2  모닝롤/고구마파이  우유/주스 계란후라이 누룽지탕/쌀밥 (쌀:국내산) 피홍합탕  감...
# 3  모닝롤/바나나샌드  우유/주스 계란후라이 새송이죽/쌀밥 (쌀:국내산) 버섯매운탕 (...
# 4  모닝롤/카스텔라  우유/주스 계란후라이 팥죽/쌀밥 (쌀:국내산) 북어계란국  느타리...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 시래기국  오리양념불고기*쌈무 (오리:국내산)...
# 1  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 소고기미역국 (소고기:호주산) 해물누룽지탕 (...
# 2  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 유부주머니국  목살스테이크 (목살:국내산) 파...
# 3  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 배추된장국  제육볶음 (돈육:국내산) 계란찜 ...
# 4  봄나물비빔밥 (쌀:국내산) 맑은국  치킨너겟 (닭:국내,수입산) 시저샐러드  마늘쫑...
#
#                                                 석식메뉴     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 닭개장 (닭:국내산) 삼치튀김*데리야끼  한식...  1110.0  651.0
# 1  오므라이스 (쌀:국내산) 가쯔오장국  돈육고구마강정 (돈육:국내산) 과일플레인샐러드...  1083.0  754.0
# 2             찹쌀밥  장각닭죽  생야채*쌈짱  오렌지  하루야채주스  포기김치    1022.0  526.0
# 3  멸치주먹밥 (쌀,현미흑미:국내산) 우동  해물까스*와사비소스  꽃맛살샐러드  무피클...   955.0  645.0
# 4  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 시금치국  언양식불고기 (돈육:수입산) 꽁치감...   839.0  377.0

# %%
test.head()
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2021-01-27  수   2983      88     182               5        358.0
# 1  2021-01-28  목   2983     104     212             409        348.0
# 2  2021-01-29  금   2983     270     249               0        294.0
# 3  2021-02-01  월   2924     108     154             538        322.0
# 4  2021-02-02  화   2924      62     186             455        314.0
#
#                                                 조식메뉴  \
# 0  모닝롤/연유버터베이글 우유/주스 계란후라이/찐계란 단호박죽/흑미밥 우거지국 고기완자...
# 1  모닝롤/대만샌드위치 우유/주스 계란후라이/찐계란 누룽지탕/흑미밥 황태국 시래기지짐 ...
# 2  모닝롤/핫케익 우유/주스 계란후라이/찐계란 오곡죽/흑미밥 매생이굴국 고구마순볶음 양...
# 3  모닝롤/촉촉한치즈케익 우유/주스 계란후라이/찐계란 누룽지탕/흑미밥 두부김칫국 새우완...
# 4  모닝롤/토마토샌드 우유/주스 계란후라이/찐계란 채소죽/흑미밥 호박맑은국 오이생채 양...
#
#                                                 중식메뉴  \
# 0  쌀밥/흑미밥/찰현미밥 대구지리 매운돈갈비찜 오꼬노미계란말이 상추무침 포기김치 양상추...
# 1  쌀밥/보리밥/찰현미밥 우렁된장찌개 오리주물럭 청양부추전 수제삼색무쌈 겉절이김치 양상...
# 2  쌀밥/흑미밥/찰현미밥 팽이장국 수제돈까스*소스 가자미조림 동초나물무침 포기김치 양상...
# 3  쌀밥/흑미밥/찰현미밥 배추들깨국 오리대패불고기 시금치프리타타 부추고추장무침 포기김치...
# 4  쌀밥/팥밥/찰현미밥 부대찌개 닭살데리야끼조림 버섯탕수 세발나물무침 알타리김치/사과푸...
#
#                                             석식메뉴
# 0  흑미밥 얼큰순두부찌개 쇠고기우엉볶음 버섯햄볶음 (New)아삭이고추무절임 포기김치
# 1            충무김밥 우동국물 오징어무침 꽃맛살샐러드 얼갈이쌈장무침 석박지
# 2            흑미밥 물만둣국 카레찜닭 숯불양념꼬지어묵 꼬시래기무침 포기김치
# 3           흑미밥 동태탕 돈육꽈리고추장조림 당면채소무침 모자반무침 포기김치
# 4       흑미밥 바지락살국 쇠고기청경채볶음 두부구이*볶은김치 머위된장무침 백김치

# %%
train[['현본사소속재택근무자수', '중식계', '석식계']] = train[['현본사소속재택근무자수', '중식계', '석식계']].astype('int')
test['현본사소속재택근무자수'] = test['현본사소속재택근무자수'].astype('int')
train['일자'].min(), train['일자'].max(), test['일자'].min(), test['일자'].max()
# Out:
# ('2020-03-23', '2021-01-26', '2021-01-27', '2021-04-09')

# %% [markdown]
# ####  df  = train, test

# %%
df = train2.append(test)
df

df['일자'] = pd.to_datetime(df['일자'])
# df['년'] = df['일자'].dt.year
# df['월'] = df['일자'].dt.month
# df['일'] = df['일자'].dt.day
# df['주'] = df['일자'].dt.week
# df['요일'] = df['일자'].dt.weekday



df['출근'] = df['본사정원수']-(df['본사휴가자수']+df['본사출장자수']+df['현본사소속재택근무자수'])
df['출근비율'] = df['출근']/df['본사정원수']
df['휴가비율'] = df['본사휴가자수']/df['본사정원수']
df['출장비율'] = df['본사출장자수']/df['본사정원수']
df['야근비율'] = df['본사시간외근무명령서승인건수']/df['출근']
df['재택비율'] = df['현본사소속재택근무자수']/df['본사정원수']

df['중식특식여부'] =  np.where(df['중식메뉴'].str.contains('특식')==True, 1, 0) 
df['자기개발의날여부'] = np.where( (df['석식메뉴'].str.len()<=20) & (df['출근'] >0), 1, 0)

drop_cols = ['요일','출근','조식메뉴','본사정원수','본사휴가자수','본사출장자수','본사시간외근무명령서승인건수','현본사소속재택근무자수']
df= df.drop(drop_cols, axis=1)

# %%
print(df.shape)
df.head()
# Out:
# (244, 12)
#           일자                                               중식메뉴  \
# 0 2020-03-23  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 시래기국  오리양념불고기*쌈무 (오리:국내산)...
# 1 2020-03-24  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 소고기미역국 (소고기:호주산) 해물누룽지탕 (...
# 2 2020-03-25  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 유부주머니국  목살스테이크 (목살:국내산) 파...
# 3 2020-03-26  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 배추된장국  제육볶음 (돈육:국내산) 계란찜 ...
# 4 2020-03-27  봄나물비빔밥 (쌀:국내산) 맑은국  치킨너겟 (닭:국내,수입산) 시저샐러드  마늘쫑...
#
#                                                 석식메뉴     중식계    석식계      출근비율  \
# 0  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 닭개장 (닭:국내산) 삼치튀김*데리야끼  한식...  1110.0  651.0  0.806102
# 1  오므라이스 (쌀:국내산) 가쯔오장국  돈육고구마강정 (돈육:국내산) 과일플레인샐러드...  1083.0  754.0  0.806441
# 2             찹쌀밥  장각닭죽  생야채*쌈짱  오렌지  하루야채주스  포기김치    1022.0  526.0  0.806441
# 3  멸치주먹밥 (쌀,현미흑미:국내산) 우동  해물까스*와사비소스  꽃맛살샐러드  무피클...   955.0  645.0  0.812203
# 4  쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 시금치국  언양식불고기 (돈육:수입산) 꽁치감...   839.0  377.0  0.772881
#
#        휴가비율      출장비율      야근비율      재택비율  중식특식여부  자기개발의날여부
# 0  0.036949  0.060339  0.288898  0.096610       0         0
# 1  0.044407  0.046441  0.268600  0.102712       0         0
# 2  0.041356  0.049492  0.000420  0.102712       0         0
# 3  0.045085  0.045085  0.243740  0.097627       0         0
# 4  0.086102  0.052881  0.000000  0.088136       0         0

# %%
before_dataset = pd.to_datetime(df.loc[0,'일자']).min() - dt.timedelta(days=1)
after_dataset = pd.to_datetime(df.loc[0,'일자']).max() + dt.timedelta(days=1)
before_dataset = before_dataset.strftime("%Y-%m-%d")
after_dataset = after_dataset.strftime("%Y-%m-%d")
before_dataset, after_dataset
# Out:
# ('2020-03-22', '2021-01-28')

# %% [markdown]
# ## 공휴일 공통함수
# <pre>
# 서비스 URL: http://apis.data.go.kr/B090041/openapi/service/SpcdeInfoService/{서비스오퍼레이션}
#
# 서비스	종류		오퍼레이션명
# -----	------	--------------
# 국경일 정보조회	getHoliDeInfo	01: 국경일 (ex: 어린이날, 광복절, 개천절)
# 공휴일 정보조회	getRestDeInfo
# 기념일 정보조회	getAnniversaryInfo	02: 기념일 (ex: 의병의 날, 정보보호의 날, 4/19 혁명 기념일)
# 24절기 정보조회	get24DivisionsInfo	03: 24절기 (ex: 청명, 경칩, 하지)
# 잡절   정보조회	getSundryDayInfo	04: 잡절 (ex: 단오, 한식)
# </pre>

# %%
## 공휴일

import requests
from urllib import parse
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

def get_holiday(syear=2020, eyear=2021 ) :
    api_key_utf8 = "pLlZwGigTf4euiGFUdQ7ktJfpWwXA5CiHJPPtfQgwx45SHhTgIiEjF4k72HaTqHiet8qB%2F0JYw1XYOUH%2FKlRSw%3D%3D"
    api_key_decode = parse.unquote(api_key_utf8)
    operation_name_list =['getHoliDeInfo'] #,'getAnniversaryInfo','get24DivisionsInfo','getSundryDayInfo']
    
    item_list = []
    for holiday_type in operation_name_list:
        url = "http://apis.data.go.kr/B090041/openapi/service/SpcdeInfoService/" + holiday_type
        for year in np.arange(syear, eyear+1) : 
            params = {
                "ServiceKey": api_key_decode,
                "solYear": year,
                "numOfRows": 100
            }

            response = requests.get(url, params=params)
            xml = BeautifulSoup(response.text, "lxml")
            items = xml.find('items')
            item_dict = {}
            for item in items:
                item_dict = {
                    "날짜": datetime.strptime(item.find("locdate").text.strip(), '%Y%m%d'),
                    "휴일여부": item.find("isholiday").text.strip(),
                    "종류" : item.find("datekind").text.strip(),
                    "이름":  item.find("datename").text.strip()
                }
                item_list.append(item_dict)
            res_df = pd.DataFrame(item_list)
            res_df = res_df.fillna('')
            res_df['휴일여부'].replace('Y', 1, inplace=True)
            res_df['휴일여부'].replace('N', 0, inplace=True)
            res_df['휴일여부'].fillna(0)
            res_df['휴일여부'] = res_df['휴일여부'].astype('int')
            # res_df['휴일여부'] = res_df['일자'].apply(lambda x:  1 if x in list else 0)
    return res_df

# %% [markdown]
# #### min date ~ max date 날짜 전체

# %%
start_date = pd.to_datetime(df['일자'].min())  #.year
end_date = pd.to_datetime(df['일자'].max())   #.year
dates = pd.date_range(start_date,end_date,freq='D') 
date_df = pd.DataFrame({'날짜':dates})
date_df.head()
# Out:
#           날짜
# 0 2020-03-23
# 1 2020-03-24
# 2 2020-03-25
# 3 2020-03-26
# 4 2020-03-27

# %% [markdown]
# #### min date ~ max date 날짜 사이의 공휴일

# %%
#외부데이터 적용

start_year = pd.to_datetime(before_dataset).year  #df['일자'].min()).year
end_year = pd.to_datetime(after_dataset).year   #df['일자'].max()).year
holiday_df = get_holiday(start_year,end_year)
holiday_df.head()
# Out:
#           날짜  휴일여부  종류    이름
# 0 2020-01-01     1  01  1월1일
# 1 2020-01-24     1  01    설날
# 2 2020-01-25     1  01    설날
# 3 2020-01-26     1  01    설날
# 4 2020-01-27     1  01    설날

# %% [markdown]
# #### 달력만들기 : 날짜 전체 , 공휴일 merge, 년, 월, 일, 주, 요일 피쳐 추가

# %%
cal_df = pd.merge(date_df, holiday_df[holiday_df['종류']=='01'] , on='날짜', how='left')
cal_df = cal_df[['날짜','휴일여부']]  
cal_df.fillna(0, inplace=True)
cal_df['휴일여부'] = cal_df['휴일여부'].astype('int')
cal_df.head()
# Out:
#           날짜  휴일여부
# 0 2020-03-23     0
# 1 2020-03-24     0
# 2 2020-03-25     0
# 3 2020-03-26     0
# 4 2020-03-27     0

# %%
# cal_df['휴일여부'].fillna(0, inplace=True)
# cal_df['휴일여부'] = cal_df['휴일여부'].astype('int')
# cal_df = cal_df.fillna('')
# cal_df['년'] = cal_df['날짜'].dt.year
# cal_df['월'] = cal_df['날짜'].dt.month
# cal_df['일'] = cal_df['날짜'].dt.day
# cal_df['주'] = cal_df['날짜'].dt.week
# cal_df['요일'] = cal_df['날짜'].dt.weekday
# cal_df.loc[(cal_df['요일']==5) | (cal_df['요일']==6), '휴일여부'] = 1
# cal_df['코로나발생'] = cal_df['년'].apply(lambda x:  1 if x>=2020 else 0)
# cal_df.head()

cal_df['휴일여부'].fillna(0, inplace=True)
cal_df['휴일여부'] = cal_df['휴일여부'].astype('int')
cal_df = cal_df.fillna('')
cal_df['년'] = cal_df['날짜'].dt.year
cal_df['월'] = cal_df['날짜'].dt.month
cal_df['일'] = cal_df['날짜'].dt.day
cal_df['주'] = cal_df['날짜'].dt.week
cal_df['요일'] = cal_df['날짜'].dt.weekday
cal_df.loc[(cal_df['요일']==5) | (cal_df['요일']==6), '휴일여부'] = 1
cal_df.head()

#날짜를 각각의 연월일주요일로 파생변수처리
# Out:
#           날짜  휴일여부     년  월   일   주  요일
# 0 2020-03-23     0  2020  3  23  13   0
# 1 2020-03-24     0  2020  3  24  13   1
# 2 2020-03-25     0  2020  3  25  13   2
# 3 2020-03-26     0  2020  3  26  13   3
# 4 2020-03-27     0  2020  3  27  13   4

# %%
cal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383 entries, 0 to 382
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      383 non-null    datetime64[ns]
#  1   휴일여부    383 non-null    int32
#  2   년       383 non-null    int64
#  3   월       383 non-null    int64
#  4   일       383 non-null    int64
#  5   주       383 non-null    int64
#  6   요일      383 non-null    int64
# dtypes: datetime64[ns](1), int32(1), int64(5)
# memory usage: 22.4 KB

# %%
cal_df.isna().sum()
# Out:
# 날짜      0
# 휴일여부    0
# 년       0
# 월       0
# 일       0
# 주       0
# 요일      0
# dtype: int64

# %%
#12열 관련 

before_dataset_holiday = 0
if before_dataset in cal_df['날짜']:
    before_dataset_holiday = 1

after_dataset_holiday = 0
if after_dataset in cal_df['날짜']:
    after_dataset_holiday = 1
before_dataset_holiday, after_dataset_holiday
# Out:
# (0, 0)

# %%
# g = 휴일.groupby('날짜')  #  GROUP BY A
# ss = g.filter(lambda x: len(x) > 1)  #  HAVING COUNT(*) > 1
# ss.head()

# cal_df['공휴일'] = cal_df['일자'].apply(lambda x:  1 if x in list else 0)

# %% [markdown]
# #### 달력(기준) , 식수정보 merge

# %%
cdf = pd.merge(cal_df, df,
             how='left', # left, right, inner (default), outer
             left_on='날짜', right_on='일자')

# %%
menu_df = cdf[['중식메뉴','석식메뉴']].copy()
drop_cols = ['일자','중식메뉴','석식메뉴']
cdf= cdf.drop(drop_cols, axis=1)
cdf.head()
# Out:
#           날짜  휴일여부     년  월   일   주  요일     중식계    석식계      출근비율      휴가비율  \
# 0 2020-03-23     0  2020  3  23  13   0  1110.0  651.0  0.806102  0.036949
# 1 2020-03-24     0  2020  3  24  13   1  1083.0  754.0  0.806441  0.044407
# 2 2020-03-25     0  2020  3  25  13   2  1022.0  526.0  0.806441  0.041356
# 3 2020-03-26     0  2020  3  26  13   3   955.0  645.0  0.812203  0.045085
# 4 2020-03-27     0  2020  3  27  13   4   839.0  377.0  0.772881  0.086102
#
#        출장비율      야근비율      재택비율  중식특식여부  자기개발의날여부
# 0  0.060339  0.288898  0.096610     0.0       0.0
# 1  0.046441  0.268600  0.102712     0.0       0.0
# 2  0.049492  0.000420  0.102712     0.0       0.0
# 3  0.045085  0.243740  0.097627     0.0       0.0
# 4  0.052881  0.000000  0.088136     0.0       0.0

# %%
cdf['전일휴일'] = cdf['휴일여부'].shift(1)
cdf['다음날휴일'] = cdf['휴일여부'].shift(-1)

# %%
cdf.head()
# Out:
#           날짜  휴일여부     년  월   일   주  요일     중식계    석식계      출근비율      휴가비율  \
# 0 2020-03-23     0  2020  3  23  13   0  1110.0  651.0  0.806102  0.036949
# 1 2020-03-24     0  2020  3  24  13   1  1083.0  754.0  0.806441  0.044407
# 2 2020-03-25     0  2020  3  25  13   2  1022.0  526.0  0.806441  0.041356
# 3 2020-03-26     0  2020  3  26  13   3   955.0  645.0  0.812203  0.045085
# 4 2020-03-27     0  2020  3  27  13   4   839.0  377.0  0.772881  0.086102
#
#        출장비율      야근비율      재택비율  중식특식여부  자기개발의날여부  전일휴일  다음날휴일
# 0  0.060339  0.288898  0.096610     0.0       0.0   NaN    0.0
# 1  0.046441  0.268600  0.102712     0.0       0.0   0.0    0.0
# 2  0.049492  0.000420  0.102712     0.0       0.0   0.0    0.0
# 3  0.045085  0.243740  0.097627     0.0       0.0   0.0    0.0
# 4  0.052881  0.000000  0.088136     0.0       0.0   0.0    1.0

# %%
cdf.shape
# Out:
# (383, 18)

# %%
#전일, 다음날 휴일 여부 결측처리
cdf.at[0,'전일휴일'] = before_dataset_holiday #20열
cdf.at[cdf.shape[0]-1,'다음날휴일'] =  after_dataset_holiday

# %%
#cdf 결측확인
cdf.isna().sum()
# Out:
# 날짜            0
# 휴일여부          0
# 년             0
# 월             0
# 일             0
# 주             0
# 요일            0
# 중식계         189
# 석식계         189
# 출근비율        139
# 휴가비율        139
# 출장비율        139
# 야근비율        139
# 재택비율        139
# 중식특식여부      139
# 자기개발의날여부    139
# 전일휴일          0
# 다음날휴일         0
# dtype: int64

# %%
# cdf 결측처리

cdf.fillna(0, inplace=True)
cdf[['중식특식여부','자기개발의날여부','전일휴일','다음날휴일']] = cdf[['중식특식여부','자기개발의날여부','전일휴일','다음날휴일']].astype('int')

# %%
cdf.isna().sum()
# Out:
# 날짜          0
# 휴일여부        0
# 년           0
# 월           0
# 일           0
# 주           0
# 요일          0
# 중식계         0
# 석식계         0
# 출근비율        0
# 휴가비율        0
# 출장비율        0
# 야근비율        0
# 재택비율        0
# 중식특식여부      0
# 자기개발의날여부    0
# 전일휴일        0
# 다음날휴일       0
# dtype: int64

# %%
# cdf = cdf.set_index('날짜')
cdf.head()
# Out:
#           날짜  휴일여부     년  월   일   주  요일     중식계    석식계      출근비율      휴가비율  \
# 0 2020-03-23     0  2020  3  23  13   0  1110.0  651.0  0.806102  0.036949
# 1 2020-03-24     0  2020  3  24  13   1  1083.0  754.0  0.806441  0.044407
# 2 2020-03-25     0  2020  3  25  13   2  1022.0  526.0  0.806441  0.041356
# 3 2020-03-26     0  2020  3  26  13   3   955.0  645.0  0.812203  0.045085
# 4 2020-03-27     0  2020  3  27  13   4   839.0  377.0  0.772881  0.086102
#
#        출장비율      야근비율      재택비율  중식특식여부  자기개발의날여부  전일휴일  다음날휴일
# 0  0.060339  0.288898  0.096610       0         0     0      0
# 1  0.046441  0.268600  0.102712       0         0     0      0
# 2  0.049492  0.000420  0.102712       0         0     0      0
# 3  0.045085  0.243740  0.097627       0         0     0      0
# 4  0.052881  0.000000  0.088136       0         0     0      1

# %%
# 타겟에 영향미치는 피쳐 상관도 

중식계_corr_feature  = cdf.corr().nlargest(20, '중식계').index
print(중식계_corr_feature)
plt.figure(figsize=(12,8))
sns.heatmap(cdf[중식계_corr_feature].corr(), annot=True, cmap='Blues', fmt='0.2f')
plt.show()
# Out:
# Index(['중식계', '석식계', '출근비율', '재택비율', '출장비율', '야근비율', '휴가비율', '월', '주',
#        '자기개발의날여부', '일', '전일휴일', '다음날휴일', '년', '요일', '휴일여부'],
#       dtype='object')

# %%
# 중식계에 정비례/반비례하게 영향미치는 피쳐5개

print(cdf.corrwith(cdf["중식계"]).sort_values(ascending=False)[:5])
print(cdf.corrwith(cdf["중식계"]).sort_values(ascending=False)[-5:])
# Out:
# 중식계     1.000000
# 석식계     0.959530
# 출근비율    0.718418
# 재택비율    0.635973
# 출장비율    0.612051
# dtype: float64
# 다음날휴일    -0.326256
# 년        -0.346320
# 요일       -0.605600
# 휴일여부     -0.649044
# 중식특식여부         NaN
# dtype: float64

# %%
# 석식계에 정비례/반비례하게 영향미치는 피쳐5개

print(cdf.corrwith(cdf["석식계"]).sort_values(ascending=False)[:5])
print(cdf.corrwith(cdf["석식계"]).sort_values(ascending=False)[-5:])
# Out:
# 석식계     1.000000
# 중식계     0.959530
# 출근비율    0.699365
# 재택비율    0.617894
# 야근비율    0.593167
# dtype: float64
# 다음날휴일    -0.345798
# 년        -0.371587
# 요일       -0.590453
# 휴일여부     -0.629013
# 중식특식여부         NaN
# dtype: float64

# %%
cdf.head(20)
# Out:
#            날짜  휴일여부     년  월   일   주  요일     중식계    석식계      출근비율      휴가비율  \
# 0  2020-03-23     0  2020  3  23  13   0  1110.0  651.0  0.806102  0.036949
# 1  2020-03-24     0  2020  3  24  13   1  1083.0  754.0  0.806441  0.044407
# 2  2020-03-25     0  2020  3  25  13   2  1022.0  526.0  0.806441  0.041356
# 3  2020-03-26     0  2020  3  26  13   3   955.0  645.0  0.812203  0.045085
# 4  2020-03-27     0  2020  3  27  13   4   839.0  377.0  0.772881  0.086102
# 5  2020-03-28     1  2020  3  28  13   5     0.0    0.0  0.000000  0.000000
# 6  2020-03-29     1  2020  3  29  13   6     0.0    0.0  0.000000  0.000000
# 7  2020-03-30     0  2020  3  30  14   0  1000.0  625.0  0.738644  0.077966
# 8  2020-03-31     0  2020  3  31  14   1   859.0  601.0  0.739322  0.065424
# 9  2020-04-01     0  2020  4   1  14   2   939.0  561.0  0.762323  0.076975
# 10 2020-04-02     0  2020  4   2  14   3  1009.0  645.0  0.756921  0.079676
# 11 2020-04-03     0  2020  4   3  14   4   802.0  318.0  0.716745  0.118163
# 12 2020-04-04     1  2020  4   4  14   5     0.0    0.0  0.000000  0.000000
# 13 2020-04-05     1  2020  4   5  14   6     0.0    0.0  0.000000  0.000000
# 14 2020-04-06     0  2020  4   6  15   0  1161.0  655.0  0.718096  0.069548
# 15 2020-04-07     0  2020  4   7  15   1   969.0  634.0  0.726536  0.055368
# 16 2020-04-08     0  2020  4   8  15   2  1032.0  445.0  0.726536  0.053680
# 17 2020-04-09     0  2020  4   9  15   3   880.0  458.0  0.720459  0.051992
# 18 2020-04-10     0  2020  4  10  15   4   780.0  302.0  0.681972  0.106685
# 19 2020-04-11     1  2020  4  11  15   5     0.0    0.0  0.000000  0.000000
#
#         출장비율      야근비율      재택비율  중식특식여부  자기개발의날여부  전일휴일  다음날휴일
# 0   0.060339  0.288898  0.096610       0         0     0      0
# 1   0.046441  0.268600  0.102712       0         0     0      0
# 2   0.049492  0.000420  0.102712       0         0     0      0
# 3   0.045085  0.243740  0.097627       0         0     0      0
# 4   0.052881  0.000000  0.088136       0         0     0      1
# 5   0.000000  0.000000  0.000000       0         0     0      1
# 6   0.000000  0.000000  0.000000       0         0     1      0
# 7   0.017966  0.287747  0.165424       0         0     1      0
# 8   0.014576  0.242091  0.180678       0         0     0      0
# 9   0.018906  0.000000  0.141796       0         0     0      0
# 10  0.030047  0.218555  0.133356       0         0     0      0
# 11  0.050304  0.000471  0.114787       0         0     0      1
# 12  0.000000  0.000000  0.000000       0         0     0      1
# 13  0.000000  0.000000  0.000000       0         0     1      0
# 14  0.051317  0.335214  0.161040       0         0     1      0
# 15  0.052667  0.324349  0.165429       0         0     0      0
# 16  0.058069  0.000465  0.161715       0         0     0      0
# 17  0.062795  0.254920  0.164754       0         0     0      0
# 18  0.070560  0.000000  0.140783       0         0     0      1
# 19  0.000000  0.000000  0.000000       0         0     0      1

# %%
cdf.shape
# Out:
# (383, 18)

# %% [markdown]
# ### 카레고리화

# %%
# cdf.loc[:, ['월', '일', '주', '요일']] = cdf.loc[:, ['월', '일', '주', '요일']].astype('str')
# cdf.info()

# %%
# cdf = pd.get_dummies(cdf)
# cdf.shape

# %% [markdown]
# ## 1. 달력형 train 원본 test

# %%
# ((1205, 12), (50, 10))
train['일자'].min(), train['일자'].max(), test['일자'].min(), test['일자'].max()
# Out:
# ('2020-03-23', '2021-01-26', '2021-01-27', '2021-04-09')

# %%
#확인용
print(cdf['날짜'][:5])
print(cdf['날짜'][-5:])
print(train['일자'][:5])
print(train['일자'][-5:])
print(cdf.shape, train.shape, test.shape)
# Out:
# 0   2020-03-23
# 1   2020-03-24
# 2   2020-03-25
# 3   2020-03-26
# 4   2020-03-27
# Name: 날짜, dtype: datetime64[ns]
# 378   2021-04-05
# 379   2021-04-06
# 380   2021-04-07
# 381   2021-04-08
# 382   2021-04-09
# Name: 날짜, dtype: datetime64[ns]
# 1011    2020-03-23
# 1012    2020-03-24
# 1013    2020-03-25
# 1014    2020-03-26
# 1015    2020-03-27
# Name: 일자, dtype: object
# 1200    2021-01-20
# 1201    2021-01-21
# 1202    2021-01-22
# 1203    2021-01-25
# 1204    2021-01-26
# Name: 일자, dtype: object
# (383, 18) (194, 12) (50, 10)

# %%
cdf_train = cdf[cdf['날짜'] <= train['일자'].max()]#train, test 나누기
cdf_test = cdf[cdf['날짜'] > train['일자'].max()]
cdf_test  = cdf_test[cdf_test['날짜'].isin(test['일자'].values)]
# cdf_test = cdf_test.drop(['중식계','석식계'], axis=1)
print(cdf_train.shape, cdf_test.shape)
# print(cdf_train['날짜'].min(), cdf_train['날짜'].max(), cdf_test['날짜'].min(), cdf_test['날짜'].max())
# Out:
# (310, 18) (50, 18)

# %%
#확인용
print(cdf_train.head(1))
print("==="*30)
print(cdf_test.head(1))
# Out:
#           날짜  휴일여부     년  월   일   주  요일     중식계    석식계      출근비율      휴가비율  \
# 0 2020-03-23     0  2020  3  23  13   0  1110.0  651.0  0.806102  0.036949
#
#        출장비율      야근비율     재택비율  중식특식여부  자기개발의날여부  전일휴일  다음날휴일
# 0  0.060339  0.288898  0.09661       0         0     0      0
# ==========================================================================================
#             날짜  휴일여부     년  월   일  주  요일  중식계  석식계      출근비율      휴가비율  \
# 310 2021-01-27     0  2021  1  27  4   2  0.0  0.0  0.789474  0.029501
#
#          출장비율      야근비율      재택비율  중식특식여부  자기개발의날여부  전일휴일  다음날휴일
# 310  0.061012  0.002123  0.120013       0         0     0      0

# %%
cdf_train = cdf_train.drop('날짜', axis=1) #연월일 만들었으니까 제거
cdf_test = cdf_test.drop('날짜', axis=1)

# %%
cdf_train.shape,cdf_test.shape #컬럼수 맞췄는지 확인
# Out:
# ((310, 17), (50, 17))

# %%
cdf_test.head() #컬럼 확인
# Out:
#      휴일여부     년  월   일  주  요일  중식계  석식계      출근비율      휴가비율      출장비율  \
# 310     0  2021  1  27  4   2  0.0  0.0  0.789474  0.029501  0.061012
# 311     0  2021  1  28  4   3  0.0  0.0  0.777405  0.034864  0.071069
# 312     0  2021  1  29  4   4  0.0  0.0  0.727456  0.090513  0.083473
# 315     0  2021  2   1  5   0  0.0  0.0  0.800274  0.036936  0.052668
# 316     0  2021  2   2  5   1  0.0  0.0  0.807798  0.021204  0.063611
#
#          야근비율      재택비율  중식특식여부  자기개발의날여부  전일휴일  다음날휴일
# 310  0.002123  0.120013       0         0     0      0
# 311  0.176369  0.116661       0         0     0      0
# 312  0.000000  0.098558       0         0     0      1
# 315  0.229915  0.110123       0         0     1      0
# 316  0.192633  0.107387       0         0     0      0

# %% [markdown]
# # 예측 모델

# %%
submission_esb = pd.read_csv('./sample_submission.csv') #제출 파일 미리 불러오기
print(submission_esb.shape, cdf_test.shape)
submission_esb.head()
# Out:
# (50, 3) (50, 17)
#            일자  중식계  석식계
# 0  2021-01-27    0    0
# 1  2021-01-28    0    0
# 2  2021-01-29    0    0
# 3  2021-02-01    0    0
# 4  2021-02-02    0    0

# %% [markdown]
# ### pycaret
# * ref : https://pycaret.readthedocs.io/en/latest/api/classification.html

# %% [markdown]
# ### 중식계 예측

# %%
reg = setup(data=cdf_train,
            target='중식계',
            numeric_imputation = 'mean',
            normalize = True,
            data_split_shuffle= False,
            silent= True,
           normalize_method='robust',  #minmax IQR기준으로 스케일링
           fold_strategy = "kfold", # kfold, skfold, timeseries 등
            fold=20
           )
# Out:
# <style type="text/css">
# #T_2c720_row27_col1, #T_2c720_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2c720_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c720_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c720_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_2c720_row0_col1" class="data row0 col1" >2776</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c720_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2c720_row1_col1" class="data row1 col1" >중식계</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c720_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_2c720_row2_col1" class="data row2 col1" >(310, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c720_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_2c720_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2c720_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_2c720_row4_col1" class="data row4 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c720_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_2c720_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c720_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_2c720_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c720_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_2c720_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2c720_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_2c720_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2c720_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_2c720_row9_col1" class="data row9 col1" >(216, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2c720_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_2c720_row10_col1" class="data row10 col1" >(94, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2c720_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_2c720_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2c720_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_2c720_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2c720_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_2c720_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2c720_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_2c720_row14_col1" class="data row14 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2c720_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_2c720_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2c720_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_2c720_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2c720_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_2c720_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2c720_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_2c720_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2c720_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_2c720_row19_col1" class="data row19 col1" >900d</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2c720_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_2c720_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2c720_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_2c720_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2c720_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_2c720_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_2c720_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_2c720_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_2c720_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_2c720_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_2c720_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_2c720_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_2c720_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_2c720_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_2c720_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_2c720_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_2c720_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_2c720_row28_col1" class="data row28 col1" >robust</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_2c720_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_2c720_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c720_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_2c720_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_2c720_row30_col1" class="data row30 col1" >None</td>

# %%
best_5_l = compare_models(sort='MAE', n_select=5)
#45.1504(rf) # fold10 :44.1489 (catboost) / fold20:	43.7880(rf) # timeseries: Regressor	48.7279(gbr) /fold20:44.9478(et)
# Out:
# IntProgress(value=0, description='Processing: ', max=99)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           18:35:00
# Status     . . . . . . . . . . . . . . . . . .   Fitting 20 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# Empty DataFrame
# Columns: [Model, MAE, MSE, RMSE, R2, RMSLE, MAPE, TT (Sec)]
# Index: []

# %%
# 앙상블 모델
blended_l = blend_models(estimator_list= best_5_l, fold=5, optimize='MAE') #47.4682 #fold 10 :47.8797 /fold20:	46.9146	  #timeseries 51.8096/fold20:48.1131
pred_holdout = predict_model(blended_l)
final_model_l = finalize_model(blended_l)
pred_esb_l = predict_model(final_model_l, cdf_test)
# submission_esb
# Out:
# <style type="text/css">
# #T_ca374_row5_col0, #T_ca374_row5_col1, #T_ca374_row5_col2, #T_ca374_row5_col3, #T_ca374_row5_col4, #T_ca374_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ca374_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca374_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca374_row0_col0" class="data row0 col0" >47.5434</td>
#       <td id="T_ca374_row0_col1" class="data row0 col1" >4299.4040</td>
#       <td id="T_ca374_row0_col2" class="data row0 col2" >65.5698</td>
#       <td id="T_ca374_row0_col3" class="data row0 col3" >0.9799</td>
#       <td id="T_ca374_row0_col4" class="data row0 col4" >0.8232</td>
#       <td id="T_ca374_row0_col5" class="data row0 col5" >0.0821</td>
#     </tr>
#     <tr>
#       <th id="T_ca374_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca374_row1_col0" class="data row1 col0" >64.4888</td>
#       <td id="T_ca374_row1_col1" class="data row1 col1" >8552.5675</td>
#       <td id="T_ca374_row1_col2" class="data row1 col2" >92.4801</td>
#       <td id="T_ca374_row1_col3" class="data row1 col3" >0.9527</td>
#       <td id="T_ca374_row1_col4" class="data row1 col4" >0.5905</td>
#       <td id="T_ca374_row1_col5" class="data row1 col5" >0.1371</td>
#     </tr>
#     <tr>
#       <th id="T_ca374_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca374_row2_col0" class="data row2 col0" >48.1113</td>
#       <td id="T_ca374_row2_col1" class="data row2 col1" >6584.7320</td>
#       <td id="T_ca374_row2_col2" class="data row2 col2" >81.1464</td>
#       <td id="T_ca374_row2_col3" class="data row2 col3" >0.9667</td>
#       <td id="T_ca374_row2_col4" class="data row2 col4" >0.9100</td>
#       <td id="T_ca374_row2_col5" class="data row2 col5" >0.1076</td>
#     </tr>
#     <tr>
#       <th id="T_ca374_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ca374_row3_col0" class="data row3 col0" >41.4779</td>
#       <td id="T_ca374_row3_col1" class="data row3 col1" >3935.2129</td>
#       <td id="T_ca374_row3_col2" class="data row3 col2" >62.7313</td>
#       <td id="T_ca374_row3_col3" class="data row3 col3" >0.9783</td>
#       <td id="T_ca374_row3_col4" class="data row3 col4" >0.5660</td>
#       <td id="T_ca374_row3_col5" class="data row3 col5" >0.0708</td>
#     </tr>
#     <tr>
#       <th id="T_ca374_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ca374_row4_col0" class="data row4 col0" >33.6499</td>
#       <td id="T_ca374_row4_col1" class="data row4 col1" >3456.3589</td>
#       <td id="T_ca374_row4_col2" class="data row4 col2" >58.7908</td>
#       <td id="T_ca374_row4_col3" class="data row4 col3" >0.9831</td>
#       <td id="T_ca374_row4_col4" class="data row4 col4" >0.8468</td>
#       <td id="T_ca374_row4_col5" class="data row4 col5" >0.0791</td>
#     </tr>
#     <tr>
#       <th id="T_ca374_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_ca374_row5_col0" class="data row5 col0" >47.0543</td>
#       <td id="T_ca374_row5_col1" class="data row5 col1" >5365.6551</td>
#       <td id="T_ca374_row5_col2" class="data row5 col2" >72.1437</td>
#       <td id="T_ca374_row5_col3" class="data row5 col3" >0.9721</td>
#       <td id="T_ca374_row5_col4" class="data row5 col4" >0.7473</td>
#       <td id="T_ca374_row5_col5" class="data row5 col5" >0.0953</td>
#     </tr>
#     <tr>
#       <th id="T_ca374_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_ca374_row6_col0" class="data row6 col0" >10.1597</td>
#       <td id="T_ca374_row6_col1" class="data row6 col1" >1922.0316</td>
#       <td id="T_ca374_row6_col2" class="data row6 col2" >12.6864</td>
#       <td id="T_ca374_row6_col3" class="data row6 col3" >0.0112</td>
#       <td id="T_ca374_row6_col4" class="data row6 col4" >0.1411</td>
#       <td id="T_ca374_row6_col5" class="data row6 col5" >0.0242</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6ad16_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ad16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ad16_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_6ad16_row0_col1" class="data row0 col1" >80.7839</td>
#       <td id="T_6ad16_row0_col2" class="data row0 col2" >16664.7277</td>
#       <td id="T_6ad16_row0_col3" class="data row0 col3" >129.0919</td>
#       <td id="T_6ad16_row0_col4" class="data row0 col4" >0.9319</td>
#       <td id="T_6ad16_row0_col5" class="data row0 col5" >0.4104</td>
#       <td id="T_6ad16_row0_col6" class="data row0 col6" >0.1276</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_esb_l
# Out:
#      휴일여부     년  월   일   주  요일  중식계  석식계      출근비율      휴가비율      출장비율  \
# 310     0  2021  1  27   4   2  0.0  0.0  0.789474  0.029501  0.061012
# 311     0  2021  1  28   4   3  0.0  0.0  0.777405  0.034864  0.071069
# 312     0  2021  1  29   4   4  0.0  0.0  0.727456  0.090513  0.083473
# 315     0  2021  2   1   5   0  0.0  0.0  0.800274  0.036936  0.052668
# 316     0  2021  2   2   5   1  0.0  0.0  0.807798  0.021204  0.063611
# 317     0  2021  2   3   5   2  0.0  0.0  0.813953  0.020178  0.068057
# 318     0  2021  2   4   5   3  0.0  0.0  0.808482  0.020862  0.072161
# 319     0  2021  2   5   5   4  0.0  0.0  0.768468  0.057798  0.086183
# 322     0  2021  2   8   6   0  0.0  0.0  0.797880  0.030096  0.059508
# 323     0  2021  2   9   6   1  0.0  0.0  0.792750  0.032148  0.062585
# 324     0  2021  2  10   6   2  0.0  0.0  0.707250  0.167237  0.045828
# 329     0  2021  2  15   7   0  0.0  0.0  0.772914  0.060876  0.044802
# 330     0  2021  2  16   7   1  0.0  0.0  0.774966  0.023940  0.059850
# 331     0  2021  2  17   7   2  0.0  0.0  0.782148  0.026334  0.061902
# 332     0  2021  2  18   7   3  0.0  0.0  0.771546  0.028386  0.084473
# 333     0  2021  2  19   7   4  0.0  0.0  0.752394  0.060192  0.091655
# 336     0  2021  2  22   8   0  0.0  0.0  0.812244  0.035910  0.067373
# 337     0  2021  2  23   8   1  0.0  0.0  0.826265  0.025650  0.068399
# 338     0  2021  2  24   8   2  0.0  0.0  0.813269  0.026334  0.080369
# 339     0  2021  2  25   8   3  0.0  0.0  0.802326  0.031122  0.086183
# 340     0  2021  2  26   8   4  0.0  0.0  0.754104  0.089261  0.095417
# 344     0  2021  3   2   9   1  0.0  0.0  0.814118  0.046723  0.055798
# 345     0  2021  3   3   9   2  0.0  0.0  0.819496  0.016807  0.065546
# 346     0  2021  3   4   9   3  0.0  0.0  0.808067  0.024202  0.079328
# 347     0  2021  3   5   9   4  0.0  0.0  0.784538  0.053109  0.086387
# 350     0  2021  3   8  10   0  0.0  0.0  0.821513  0.032605  0.057143
# 351     0  2021  3   9  10   1  0.0  0.0  0.822521  0.025546  0.057143
# 352     0  2021  3  10  10   2  0.0  0.0  0.822857  0.023866  0.062185
# 353     0  2021  3  11  10   3  0.0  0.0  0.806050  0.031261  0.074958
# 354     0  2021  3  12  10   4  0.0  0.0  0.753950  0.081008  0.080672
# 357     0  2021  3  15  11   0  0.0  0.0  0.802353  0.042353  0.049748
# 358     0  2021  3  16  11   1  0.0  0.0  0.781176  0.024874  0.059160
# 359     0  2021  3  17  11   2  0.0  0.0  0.780504  0.030252  0.064538
# 360     0  2021  3  18  11   3  0.0  0.0  0.768739  0.035630  0.077647
# 361     0  2021  3  19  11   4  0.0  0.0  0.739832  0.085042  0.085714
# 364     0  2021  3  22  12   0  0.0  0.0  0.781849  0.044706  0.055798
# 365     0  2021  3  23  12   1  0.0  0.0  0.786218  0.027563  0.068908
# 366     0  2021  3  24  12   2  0.0  0.0  0.786555  0.029244  0.078655
# 367     0  2021  3  25  12   3  0.0  0.0  0.773109  0.039664  0.087395
# 368     0  2021  3  26  12   4  0.0  0.0  0.729076  0.104538  0.089412
# 371     0  2021  3  29  13   0  0.0  0.0  0.792605  0.040672  0.059832
# 372     0  2021  3  30  13   1  0.0  0.0  0.800336  0.027899  0.066555
# 373     0  2021  3  31  13   2  0.0  0.0  0.791597  0.028908  0.072941
# 374     0  2021  4   1  13   3  0.0  0.0  0.782375  0.029600  0.086108
# 375     0  2021  4   2  13   4  0.0  0.0  0.740666  0.092499  0.091490
# 378     0  2021  4   5  14   0  0.0  0.0  0.788093  0.042045  0.058527
# 379     0  2021  4   6  14   1  0.0  0.0  0.794820  0.025563  0.057181
# 380     0  2021  4   7  14   2  0.0  0.0  0.783384  0.032291  0.071981
# 381     0  2021  4   8  14   3  0.0  0.0  0.775647  0.035318  0.080054
# 382     0  2021  4   9  14   4  0.0  0.0  0.745711  0.087117  0.090145
#
#          야근비율      재택비율  중식특식여부  자기개발의날여부  전일휴일  다음날휴일        Label
# 310  0.002123  0.120013       0         0     0      0   923.573983
# 311  0.176369  0.116661       0         0     0      0   853.696894
# 312  0.000000  0.098558       0         0     0      1   569.062825
# 315  0.229915  0.110123       0         0     1      0  1054.533159
# 316  0.192633  0.107387       0         0     0      0   916.343217
# 317  0.002101  0.097811       0         0     0      0   883.556199
# 318  0.201354  0.098495       0         0     0      0   850.089673
# 319  0.000000  0.087551       0         0     0      1   614.957184
# 322  0.295757  0.112517       0         0     1      0  1046.841787
# 323  0.233822  0.112517       0         0     0      0   931.733294
# 324  0.000000  0.079685       0         0     0      1   692.378522
# 329  0.351770  0.121409       0         0     1      0  1039.141063
# 330  0.359665  0.141245       0         0     0      0   935.953924
# 331  0.001312  0.129617       0         0     0      0   923.280480
# 332  0.263298  0.115595       0         0     0      0   766.931452
# 333  0.000455  0.095759       0         0     0      1   593.920655
# 336  0.342737  0.084473       0         0     1      0  1005.471289
# 337  0.324089  0.079685       0         0     0      0   863.944475
# 338  0.001262  0.080027       0         0     0      0   753.247780
# 339  0.249361  0.080369       0         0     0      0   731.748186
# 340  0.000454  0.061218       0         0     0      1   527.102787
# 344  0.322461  0.083361       0         0     1      0   979.536993
# 345  0.000410  0.098151       0         0     0      0   884.095368
# 346  0.310316  0.088403       0         0     0      0   820.588991
# 347  0.000857  0.075966       0         0     0      1   611.036220
# 350  0.384206  0.088739       0         0     1      0  1031.194366
# 351  0.409890  0.094790       0         0     0      0   940.603347
# 352  0.000408  0.091092       0         0     0      0   880.815751
# 353  0.253962  0.087731       0         0     0      0   844.090434
# 354  0.000000  0.084370       0         0     0      1   616.678853
# 357  0.361961  0.105546       0         0     1      0  1045.019290
# 358  0.283133  0.134790       0         0     0      0   910.046252
# 359  0.001723  0.124706       0         0     0      0   928.461244
# 360  0.227372  0.117983       0         0     0      0   826.760506
# 361  0.000000  0.089412       0         0     0      1   585.283235
# 364  0.303955  0.117647       0         0     1      0  1025.384084
# 365  0.294143  0.117311       0         0     0      0   901.223116
# 366  0.000000  0.105546       0         0     0      0   801.785010
# 367  0.191739  0.099832       0         0     0      0   709.107910
# 368  0.000000  0.076975       0         0     0      1   541.099408
# 371  0.279898  0.106891       0         0     1      0  1017.082347
# 372  0.262495  0.105210       0         0     0      0   894.980171
# 373  0.000000  0.106555       0         0     0      0   847.138781
# 374  0.169390  0.101917       0         0     0      0   717.135821
# 375  0.000000  0.075345       0         0     0      1   544.654250
# 378  0.300469  0.111335       0         0     1      0  1028.422416
# 379  0.269149  0.122435       0         0     0      0   899.302217
# 380  0.000429  0.112344       0         0     0      0   836.045007
# 381  0.220729  0.108981       0         0     0      0   761.205829
# 382  0.000000  0.077027       0         0     0      0   588.130265

# %%
cdf_test
# Out:
#      휴일여부     년  월   일   주  요일  중식계  석식계      출근비율      휴가비율      출장비율  \
# 310     0  2021  1  27   4   2  0.0  0.0  0.789474  0.029501  0.061012
# 311     0  2021  1  28   4   3  0.0  0.0  0.777405  0.034864  0.071069
# 312     0  2021  1  29   4   4  0.0  0.0  0.727456  0.090513  0.083473
# 315     0  2021  2   1   5   0  0.0  0.0  0.800274  0.036936  0.052668
# 316     0  2021  2   2   5   1  0.0  0.0  0.807798  0.021204  0.063611
# 317     0  2021  2   3   5   2  0.0  0.0  0.813953  0.020178  0.068057
# 318     0  2021  2   4   5   3  0.0  0.0  0.808482  0.020862  0.072161
# 319     0  2021  2   5   5   4  0.0  0.0  0.768468  0.057798  0.086183
# 322     0  2021  2   8   6   0  0.0  0.0  0.797880  0.030096  0.059508
# 323     0  2021  2   9   6   1  0.0  0.0  0.792750  0.032148  0.062585
# 324     0  2021  2  10   6   2  0.0  0.0  0.707250  0.167237  0.045828
# 329     0  2021  2  15   7   0  0.0  0.0  0.772914  0.060876  0.044802
# 330     0  2021  2  16   7   1  0.0  0.0  0.774966  0.023940  0.059850
# 331     0  2021  2  17   7   2  0.0  0.0  0.782148  0.026334  0.061902
# 332     0  2021  2  18   7   3  0.0  0.0  0.771546  0.028386  0.084473
# 333     0  2021  2  19   7   4  0.0  0.0  0.752394  0.060192  0.091655
# 336     0  2021  2  22   8   0  0.0  0.0  0.812244  0.035910  0.067373
# 337     0  2021  2  23   8   1  0.0  0.0  0.826265  0.025650  0.068399
# 338     0  2021  2  24   8   2  0.0  0.0  0.813269  0.026334  0.080369
# 339     0  2021  2  25   8   3  0.0  0.0  0.802326  0.031122  0.086183
# 340     0  2021  2  26   8   4  0.0  0.0  0.754104  0.089261  0.095417
# 344     0  2021  3   2   9   1  0.0  0.0  0.814118  0.046723  0.055798
# 345     0  2021  3   3   9   2  0.0  0.0  0.819496  0.016807  0.065546
# 346     0  2021  3   4   9   3  0.0  0.0  0.808067  0.024202  0.079328
# 347     0  2021  3   5   9   4  0.0  0.0  0.784538  0.053109  0.086387
# 350     0  2021  3   8  10   0  0.0  0.0  0.821513  0.032605  0.057143
# 351     0  2021  3   9  10   1  0.0  0.0  0.822521  0.025546  0.057143
# 352     0  2021  3  10  10   2  0.0  0.0  0.822857  0.023866  0.062185
# 353     0  2021  3  11  10   3  0.0  0.0  0.806050  0.031261  0.074958
# 354     0  2021  3  12  10   4  0.0  0.0  0.753950  0.081008  0.080672
# 357     0  2021  3  15  11   0  0.0  0.0  0.802353  0.042353  0.049748
# 358     0  2021  3  16  11   1  0.0  0.0  0.781176  0.024874  0.059160
# 359     0  2021  3  17  11   2  0.0  0.0  0.780504  0.030252  0.064538
# 360     0  2021  3  18  11   3  0.0  0.0  0.768739  0.035630  0.077647
# 361     0  2021  3  19  11   4  0.0  0.0  0.739832  0.085042  0.085714
# 364     0  2021  3  22  12   0  0.0  0.0  0.781849  0.044706  0.055798
# 365     0  2021  3  23  12   1  0.0  0.0  0.786218  0.027563  0.068908
# 366     0  2021  3  24  12   2  0.0  0.0  0.786555  0.029244  0.078655
# 367     0  2021  3  25  12   3  0.0  0.0  0.773109  0.039664  0.087395
# 368     0  2021  3  26  12   4  0.0  0.0  0.729076  0.104538  0.089412
# 371     0  2021  3  29  13   0  0.0  0.0  0.792605  0.040672  0.059832
# 372     0  2021  3  30  13   1  0.0  0.0  0.800336  0.027899  0.066555
# 373     0  2021  3  31  13   2  0.0  0.0  0.791597  0.028908  0.072941
# 374     0  2021  4   1  13   3  0.0  0.0  0.782375  0.029600  0.086108
# 375     0  2021  4   2  13   4  0.0  0.0  0.740666  0.092499  0.091490
# 378     0  2021  4   5  14   0  0.0  0.0  0.788093  0.042045  0.058527
# 379     0  2021  4   6  14   1  0.0  0.0  0.794820  0.025563  0.057181
# 380     0  2021  4   7  14   2  0.0  0.0  0.783384  0.032291  0.071981
# 381     0  2021  4   8  14   3  0.0  0.0  0.775647  0.035318  0.080054
# 382     0  2021  4   9  14   4  0.0  0.0  0.745711  0.087117  0.090145
#
#          야근비율      재택비율  중식특식여부  자기개발의날여부  전일휴일  다음날휴일
# 310  0.002123  0.120013       0         0     0      0
# 311  0.176369  0.116661       0         0     0      0
# 312  0.000000  0.098558       0         0     0      1
# 315  0.229915  0.110123       0         0     1      0
# 316  0.192633  0.107387       0         0     0      0
# 317  0.002101  0.097811       0         0     0      0
# 318  0.201354  0.098495       0         0     0      0
# 319  0.000000  0.087551       0         0     0      1
# 322  0.295757  0.112517       0         0     1      0
# 323  0.233822  0.112517       0         0     0      0
# 324  0.000000  0.079685       0         0     0      1
# 329  0.351770  0.121409       0         0     1      0
# 330  0.359665  0.141245       0         0     0      0
# 331  0.001312  0.129617       0         0     0      0
# 332  0.263298  0.115595       0         0     0      0
# 333  0.000455  0.095759       0         0     0      1
# 336  0.342737  0.084473       0         0     1      0
# 337  0.324089  0.079685       0         0     0      0
# 338  0.001262  0.080027       0         0     0      0
# 339  0.249361  0.080369       0         0     0      0
# 340  0.000454  0.061218       0         0     0      1
# 344  0.322461  0.083361       0         0     1      0
# 345  0.000410  0.098151       0         0     0      0
# 346  0.310316  0.088403       0         0     0      0
# 347  0.000857  0.075966       0         0     0      1
# 350  0.384206  0.088739       0         0     1      0
# 351  0.409890  0.094790       0         0     0      0
# 352  0.000408  0.091092       0         0     0      0
# 353  0.253962  0.087731       0         0     0      0
# 354  0.000000  0.084370       0         0     0      1
# 357  0.361961  0.105546       0         0     1      0
# 358  0.283133  0.134790       0         0     0      0
# 359  0.001723  0.124706       0         0     0      0
# 360  0.227372  0.117983       0         0     0      0
# 361  0.000000  0.089412       0         0     0      1
# 364  0.303955  0.117647       0         0     1      0
# 365  0.294143  0.117311       0         0     0      0
# 366  0.000000  0.105546       0         0     0      0
# 367  0.191739  0.099832       0         0     0      0
# 368  0.000000  0.076975       0         0     0      1
# 371  0.279898  0.106891       0         0     1      0
# 372  0.262495  0.105210       0         0     0      0
# 373  0.000000  0.106555       0         0     0      0
# 374  0.169390  0.101917       0         0     0      0
# 375  0.000000  0.075345       0         0     0      1
# 378  0.300469  0.111335       0         0     1      0
# 379  0.269149  0.122435       0         0     0      0
# 380  0.000429  0.112344       0         0     0      0
# 381  0.220729  0.108981       0         0     0      0
# 382  0.000000  0.077027       0         0     0      0

# %%
#인덱스 조정
pred_esb_l=pred_esb_l.set_index('년')
pred_esb_l=pred_esb_l.reset_index()
submission_esb['중식계'] = pred_esb_l['Label']

# %%
submission_esb
# Out:
#             일자          중식계  석식계
# 0   2021-01-27   923.573983    0
# 1   2021-01-28   853.696894    0
# 2   2021-01-29   569.062825    0
# 3   2021-02-01  1054.533159    0
# 4   2021-02-02   916.343217    0
# 5   2021-02-03   883.556199    0
# 6   2021-02-04   850.089673    0
# 7   2021-02-05   614.957184    0
# 8   2021-02-08  1046.841787    0
# 9   2021-02-09   931.733294    0
# 10  2021-02-10   692.378522    0
# 11  2021-02-15  1039.141063    0
# 12  2021-02-16   935.953924    0
# 13  2021-02-17   923.280480    0
# 14  2021-02-18   766.931452    0
# 15  2021-02-19   593.920655    0
# 16  2021-02-22  1005.471289    0
# 17  2021-02-23   863.944475    0
# 18  2021-02-24   753.247780    0
# 19  2021-02-25   731.748186    0
# 20  2021-02-26   527.102787    0
# 21  2021-03-02   979.536993    0
# 22  2021-03-03   884.095368    0
# 23  2021-03-04   820.588991    0
# 24  2021-03-05   611.036220    0
# 25  2021-03-08  1031.194366    0
# 26  2021-03-09   940.603347    0
# 27  2021-03-10   880.815751    0
# 28  2021-03-11   844.090434    0
# 29  2021-03-12   616.678853    0
# 30  2021-03-15  1045.019290    0
# 31  2021-03-16   910.046252    0
# 32  2021-03-17   928.461244    0
# 33  2021-03-18   826.760506    0
# 34  2021-03-19   585.283235    0
# 35  2021-03-22  1025.384084    0
# 36  2021-03-23   901.223116    0
# 37  2021-03-24   801.785010    0
# 38  2021-03-25   709.107910    0
# 39  2021-03-26   541.099408    0
# 40  2021-03-29  1017.082347    0
# 41  2021-03-30   894.980171    0
# 42  2021-03-31   847.138781    0
# 43  2021-04-01   717.135821    0
# 44  2021-04-02   544.654250    0
# 45  2021-04-05  1028.422416    0
# 46  2021-04-06   899.302217    0
# 47  2021-04-07   836.045007    0
# 48  2021-04-08   761.205829    0
# 49  2021-04-09   588.130265    0

# %% [markdown]
# ### 석식계 예측

# %%
reg = setup(data=cdf_train,
            target='석식계',
            numeric_imputation = 'mean',
            normalize = True,
            data_split_shuffle= False,
            silent= True,
            normalize_method='robust',  #minmax
            fold_strategy= "kfold", # kfold, skfold, timeseries 등
            fold=20
           )
# Out:
# <style type="text/css">
# #T_8963c_row27_col1, #T_8963c_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8963c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8963c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8963c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_8963c_row0_col1" class="data row0 col1" >2322</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8963c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8963c_row1_col1" class="data row1 col1" >석식계</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8963c_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_8963c_row2_col1" class="data row2 col1" >(310, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8963c_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_8963c_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8963c_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_8963c_row4_col1" class="data row4 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8963c_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_8963c_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8963c_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_8963c_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8963c_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_8963c_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8963c_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_8963c_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8963c_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_8963c_row9_col1" class="data row9 col1" >(216, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8963c_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_8963c_row10_col1" class="data row10 col1" >(94, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8963c_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_8963c_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8963c_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_8963c_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8963c_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_8963c_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8963c_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_8963c_row14_col1" class="data row14 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8963c_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_8963c_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8963c_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_8963c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8963c_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_8963c_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8963c_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_8963c_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8963c_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_8963c_row19_col1" class="data row19 col1" >b4aa</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8963c_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_8963c_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8963c_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_8963c_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8963c_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_8963c_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_8963c_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_8963c_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_8963c_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_8963c_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_8963c_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_8963c_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_8963c_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_8963c_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_8963c_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_8963c_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_8963c_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_8963c_row28_col1" class="data row28 col1" >robust</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_8963c_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_8963c_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8963c_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_8963c_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_8963c_row30_col1" class="data row30 col1" >None</td>

# %%
best_5_l = compare_models(sort='MAE', n_select=5) 
#가장 좋은 5개 모델 #	31.1356(xgboost)  #	fold 10: 30.2908 ada /fold20:	30.7808(ada)#	timeseries 30.1493ada/fold20:	31.9902(ada)
# Out:
# <style type="text/css">
# #T_dbe57_ th {
#   text-align: left;
# }
# #T_dbe57_row0_col0, #T_dbe57_row0_col2, #T_dbe57_row0_col3, #T_dbe57_row0_col4, #T_dbe57_row0_col5, #T_dbe57_row0_col6, #T_dbe57_row1_col0, #T_dbe57_row1_col1, #T_dbe57_row1_col2, #T_dbe57_row1_col3, #T_dbe57_row1_col6, #T_dbe57_row2_col0, #T_dbe57_row2_col1, #T_dbe57_row2_col4, #T_dbe57_row2_col5, #T_dbe57_row2_col6, #T_dbe57_row3_col0, #T_dbe57_row3_col1, #T_dbe57_row3_col2, #T_dbe57_row3_col3, #T_dbe57_row3_col4, #T_dbe57_row3_col5, #T_dbe57_row3_col6, #T_dbe57_row4_col0, #T_dbe57_row4_col1, #T_dbe57_row4_col2, #T_dbe57_row4_col3, #T_dbe57_row4_col4, #T_dbe57_row4_col5, #T_dbe57_row4_col6, #T_dbe57_row5_col0, #T_dbe57_row5_col1, #T_dbe57_row5_col2, #T_dbe57_row5_col3, #T_dbe57_row5_col4, #T_dbe57_row5_col5, #T_dbe57_row5_col6, #T_dbe57_row6_col0, #T_dbe57_row6_col1, #T_dbe57_row6_col2, #T_dbe57_row6_col3, #T_dbe57_row6_col4, #T_dbe57_row6_col5, #T_dbe57_row6_col6, #T_dbe57_row7_col0, #T_dbe57_row7_col1, #T_dbe57_row7_col2, #T_dbe57_row7_col3, #T_dbe57_row7_col4, #T_dbe57_row7_col5, #T_dbe57_row7_col6, #T_dbe57_row8_col0, #T_dbe57_row8_col1, #T_dbe57_row8_col2, #T_dbe57_row8_col3, #T_dbe57_row8_col4, #T_dbe57_row8_col5, #T_dbe57_row8_col6, #T_dbe57_row9_col0, #T_dbe57_row9_col1, #T_dbe57_row9_col2, #T_dbe57_row9_col3, #T_dbe57_row9_col4, #T_dbe57_row9_col5, #T_dbe57_row9_col6, #T_dbe57_row10_col0, #T_dbe57_row10_col1, #T_dbe57_row10_col2, #T_dbe57_row10_col3, #T_dbe57_row10_col4, #T_dbe57_row10_col5, #T_dbe57_row10_col6, #T_dbe57_row11_col0, #T_dbe57_row11_col1, #T_dbe57_row11_col2, #T_dbe57_row11_col3, #T_dbe57_row11_col4, #T_dbe57_row11_col5, #T_dbe57_row11_col6, #T_dbe57_row12_col0, #T_dbe57_row12_col1, #T_dbe57_row12_col2, #T_dbe57_row12_col3, #T_dbe57_row12_col4, #T_dbe57_row12_col5, #T_dbe57_row12_col6, #T_dbe57_row13_col0, #T_dbe57_row13_col1, #T_dbe57_row13_col2, #T_dbe57_row13_col3, #T_dbe57_row13_col4, #T_dbe57_row13_col5, #T_dbe57_row13_col6, #T_dbe57_row14_col0, #T_dbe57_row14_col1, #T_dbe57_row14_col2, #T_dbe57_row14_col3, #T_dbe57_row14_col4, #T_dbe57_row14_col5, #T_dbe57_row14_col6, #T_dbe57_row15_col0, #T_dbe57_row15_col1, #T_dbe57_row15_col2, #T_dbe57_row15_col3, #T_dbe57_row15_col4, #T_dbe57_row15_col5, #T_dbe57_row15_col6, #T_dbe57_row16_col0, #T_dbe57_row16_col1, #T_dbe57_row16_col2, #T_dbe57_row16_col3, #T_dbe57_row16_col4, #T_dbe57_row16_col5, #T_dbe57_row16_col6, #T_dbe57_row17_col0, #T_dbe57_row17_col1, #T_dbe57_row17_col2, #T_dbe57_row17_col3, #T_dbe57_row17_col4, #T_dbe57_row17_col5, #T_dbe57_row17_col6, #T_dbe57_row18_col0, #T_dbe57_row18_col1, #T_dbe57_row18_col2, #T_dbe57_row18_col3, #T_dbe57_row18_col4, #T_dbe57_row18_col5, #T_dbe57_row18_col6, #T_dbe57_row19_col0, #T_dbe57_row19_col1, #T_dbe57_row19_col2, #T_dbe57_row19_col3, #T_dbe57_row19_col4, #T_dbe57_row19_col5, #T_dbe57_row19_col6 {
#   text-align: left;
# }
# #T_dbe57_row0_col1, #T_dbe57_row1_col4, #T_dbe57_row1_col5, #T_dbe57_row2_col2, #T_dbe57_row2_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_dbe57_row0_col7, #T_dbe57_row1_col7, #T_dbe57_row2_col7, #T_dbe57_row3_col7, #T_dbe57_row4_col7, #T_dbe57_row5_col7, #T_dbe57_row6_col7, #T_dbe57_row7_col7, #T_dbe57_row8_col7, #T_dbe57_row9_col7, #T_dbe57_row10_col7, #T_dbe57_row12_col7, #T_dbe57_row13_col7, #T_dbe57_row14_col7, #T_dbe57_row15_col7, #T_dbe57_row16_col7, #T_dbe57_row18_col7, #T_dbe57_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_dbe57_row11_col7, #T_dbe57_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_dbe57_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbe57_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_dbe57_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_dbe57_row0_col1" class="data row0 col1" >30.6147</td>
#       <td id="T_dbe57_row0_col2" class="data row0 col2" >2567.8478</td>
#       <td id="T_dbe57_row0_col3" class="data row0 col3" >43.9296</td>
#       <td id="T_dbe57_row0_col4" class="data row0 col4" >0.8928</td>
#       <td id="T_dbe57_row0_col5" class="data row0 col5" >0.1529</td>
#       <td id="T_dbe57_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_dbe57_row0_col7" class="data row0 col7" >0.0885</td>
#     </tr>
#     <tr>
#       <th id="T_dbe57_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_dbe57_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_dbe57_row1_col1" class="data row1 col1" >31.2684</td>
#       <td id="T_dbe57_row1_col2" class="data row1 col2" >2666.2674</td>
#       <td id="T_dbe57_row1_col3" class="data row1 col3" >45.2042</td>
#       <td id="T_dbe57_row1_col4" class="data row1 col4" >0.9377</td>
#       <td id="T_dbe57_row1_col5" class="data row1 col5" >0.1164</td>
#       <td id="T_dbe57_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_dbe57_row1_col7" class="data row1 col7" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_dbe57_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_dbe57_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_dbe57_row2_col1" class="data row2 col1" >31.9941</td>
#       <td id="T_dbe57_row2_col2" class="data row2 col2" >2428.8481</td>
#       <td id="T_dbe57_row2_col3" class="data row2 col3" >42.5963</td>
#       <td id="T_dbe57_row2_col4" class="data row2 col4" >0.8947</td>
#       <td id="T_dbe57_row2_col5" class="data row2 col5" >1.1895</td>
#       <td id="T_dbe57_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_dbe57_row2_col7" class="data row2 col7" >0.0045</td>
#     </tr>
#     <tr>
#       <th id="T_dbe57_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_dbe57_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_dbe57_row3_col1" class="data row3 col1" >32.6216</td>
#       <td id="T_dbe57_row3_col2" class="data row3 col2" >3098.1090</td>
#       <td id="T_dbe57_row3_col3" class="data row3 col3" >49.1824</td>
#       <td id="T_dbe57_row3_col4" class="data row3 col4" >0.9131</td>
#       <td id="T_dbe57_row3_col5" class="data row3 col5" >0.1295</td>
#       <td id="T_dbe57_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_dbe57_row3_col7" class="data row3 col7" >0.0845</td>
#     </tr>
#     <tr>
#       <th id="T_dbe57_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_dbe57_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_dbe57_row4_col1" class="data row4 col1" >33.8444</td>
#       <td id="T_dbe57_row4_col2" class="data row4 col2" >2947.8973</td>
#       <td id="T_dbe57_row4_col3" class="data row4 col3" >48.4821</td>
#       <td id="T_dbe57_row4_col4" class="data row4 col4" >0.8819</td>
#       <td id="T_dbe57_row4_col5" class="data row4 col5" >0.1683</td>
#       <td id="T_dbe57_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_dbe57_row4_col7" class="data row4 col7" >0.1935</td>
#     </tr>
#     <tr>
#       <th id="T_dbe57_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_dbe57_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_dbe57_row5_col1" class="data row5 col1" >34.4138</td>
#       <td id="T_dbe57_row5_col2" class="data row5 col2" >3064.1192</td>
#       <td id="T_dbe57_row5_col3" class="data row5 col3" >48.8525</td>
#       <td id="T_dbe57_row5_col4" class="data row5 col4" >0.8811</td>
#       <td id="T_dbe57_row5_col5" class="data row5 col5" >0.3804</td>
#       <td id="T_dbe57_row5_col6" class="data

# %%
# 앙상블 모델 #베스트5로 앙상블 #31.0532 #fold10 :31.1775 /fold20: 31.3542	 #timeseries 533330098.1856 / fold20:	30.6891	
blended_l = blend_models(estimator_list= best_5_l, fold=5, optimize='MAE')
pred_holdout = predict_model(blended_l)
final_model_l = finalize_model(blended_l)
pred_esb_l = predict_model(final_model_l, cdf_test)
# Out:
# <style type="text/css">
# #T_f29ef_row5_col0, #T_f29ef_row5_col1, #T_f29ef_row5_col2, #T_f29ef_row5_col3, #T_f29ef_row5_col4, #T_f29ef_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f29ef_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f29ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f29ef_row0_col0" class="data row0 col0" >47.4624</td>
#       <td id="T_f29ef_row0_col1" class="data row0 col1" >5810.1533</td>
#       <td id="T_f29ef_row0_col2" class="data row0 col2" >76.2244</td>
#       <td id="T_f29ef_row0_col3" class="data row0 col3" >0.9170</td>
#       <td id="T_f29ef_row0_col4" class="data row0 col4" >0.3744</td>
#       <td id="T_f29ef_row0_col5" class="data row0 col5" >0.1799</td>
#     </tr>
#     <tr>
#       <th id="T_f29ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f29ef_row1_col0" class="data row1 col0" >21.8465</td>
#       <td id="T_f29ef_row1_col1" class="data row1 col1" >1057.6043</td>
#       <td id="T_f29ef_row1_col2" class="data row1 col2" >32.5208</td>
#       <td id="T_f29ef_row1_col3" class="data row1 col3" >0.9754</td>
#       <td id="T_f29ef_row1_col4" class="data row1 col4" >0.3982</td>
#       <td id="T_f29ef_row1_col5" class="data row1 col5" >0.0813</td>
#     </tr>
#     <tr>
#       <th id="T_f29ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f29ef_row2_col0" class="data row2 col0" >22.7642</td>
#       <td id="T_f29ef_row2_col1" class="data row2 col1" >1461.1529</td>
#       <td id="T_f29ef_row2_col2" class="data row2 col2" >38.2250</td>
#       <td id="T_f29ef_row2_col3" class="data row2 col3" >0.9639</td>
#       <td id="T_f29ef_row2_col4" class="data row2 col4" >0.6078</td>
#       <td id="T_f29ef_row2_col5" class="data row2 col5" >0.1257</td>
#     </tr>
#     <tr>
#       <th id="T_f29ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f29ef_row3_col0" class="data row3 col0" >30.9989</td>
#       <td id="T_f29ef_row3_col1" class="data row3 col1" >1891.2944</td>
#       <td id="T_f29ef_row3_col2" class="data row3 col2" >43.4890</td>
#       <td id="T_f29ef_row3_col3" class="data row3 col3" >0.9595</td>
#       <td id="T_f29ef_row3_col4" class="data row3 col4" >0.4203</td>
#       <td id="T_f29ef_row3_col5" class="data row3 col5" >0.1047</td>
#     </tr>
#     <tr>
#       <th id="T_f29ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f29ef_row4_col0" class="data row4 col0" >33.7083</td>
#       <td id="T_f29ef_row4_col1" class="data row4 col1" >2769.5677</td>
#       <td id="T_f29ef_row4_col2" class="data row4 col2" >52.6267</td>
#       <td id="T_f29ef_row4_col3" class="data row4 col3" >0.9430</td>
#       <td id="T_f29ef_row4_col4" class="data row4 col4" >1.1121</td>
#       <td id="T_f29ef_row4_col5" class="data row4 col5" >0.1401</td>
#     </tr>
#     <tr>
#       <th id="T_f29ef_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_f29ef_row5_col0" class="data row5 col0" >31.3561</td>
#       <td id="T_f29ef_row5_col1" class="data row5 col1" >2597.9545</td>
#       <td id="T_f29ef_row5_col2" class="data row5 col2" >48.6172</td>
#       <td id="T_f29ef_row5_col3" class="data row5 col3" >0.9518</td>
#       <td id="T_f29ef_row5_col4" class="data row5 col4" >0.5826</td>
#       <td id="T_f29ef_row5_col5" class="data row5 col5" >0.1263</td>
#     </tr>
#     <tr>
#       <th id="T_f29ef_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_f29ef_row6_col0" class="data row6 col0" >9.2663</td>
#       <td id="T_f29ef_row6_col1" class="data row6 col1" >1703.6454</td>
#       <td id="T_f29ef_row6_col2" class="data row6 col2" >15.3076</td>
#       <td id="T_f29ef_row6_col3" class="data row6 col3" >0.0203</td>
#       <td id="T_f29ef_row6_col4" class="data row6 col4" >0.2774</td>
#       <td id="T_f29ef_row6_col5" class="data row6 col5" >0.0333</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_97423_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97423_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97423_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_97423_row0_col1" class="data row0 col1" >62.3595</td>
#       <td id="T_97423_row0_col2" class="data row0 col2" >9078.6690</td>
#       <td id="T_97423_row0_col3" class="data row0 col3" >95.2820</td>
#       <td id="T_97423_row0_col4" class="data row0 col4" >0.8307</td>
#       <td id="T_97423_row0_col5" class="data row0 col5" >1.6194</td>
#       <td id="T_97423_row0_col6" class="data row0 col6" >0.2328</td>
#     </tr>
#   </tbody>
# </table>

# %%
cat = create_model('rf')
evaluate_model(estimator=cat, fold=5) # plot type 눌러보셈
# Out:
# <style type="text/css">
# #T_a05ef_row20_col0, #T_a05ef_row20_col1, #T_a05ef_row20_col2, #T_a05ef_row20_col3, #T_a05ef_row20_col4, #T_a05ef_row20_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a05ef_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a05ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a05ef_row0_col0" class="data row0 col0" >102.5400</td>
#       <td id="T_a05ef_row0_col1" class="data row0 col1" >15162.6283</td>
#       <td id="T_a05ef_row0_col2" class="data row0 col2" >123.1366</td>
#       <td id="T_a05ef_row0_col3" class="data row0 col3" >0.7524</td>
#       <td id="T_a05ef_row0_col4" class="data row0 col4" >0.2228</td>
#       <td id="T_a05ef_row0_col5" class="data row0 col5" >0.2035</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a05ef_row1_col0" class="data row1 col0" >28.3700</td>
#       <td id="T_a05ef_row1_col1" class="data row1 col1" >1432.9918</td>
#       <td id="T_a05ef_row1_col2" class="data row1 col2" >37.8549</td>
#       <td id="T_a05ef_row1_col3" class="data row1 col3" >0.9779</td>
#       <td id="T_a05ef_row1_col4" class="data row1 col4" >0.0833</td>
#       <td id="T_a05ef_row1_col5" class="data row1 col5" >0.0997</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a05ef_row2_col0" class="data row2 col0" >16.9682</td>
#       <td id="T_a05ef_row2_col1" class="data row2 col1" >763.4006</td>
#       <td id="T_a05ef_row2_col2" class="data row2 col2" >27.6297</td>
#       <td id="T_a05ef_row2_col3" class="data row2 col3" >0.9837</td>
#       <td id="T_a05ef_row2_col4" class="data row2 col4" >0.0709</td>
#       <td id="T_a05ef_row2_col5" class="data row2 col5" >0.0556</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a05ef_row3_col0" class="data row3 col0" >25.7000</td>
#       <td id="T_a05ef_row3_col1" class="data row3 col1" >2538.4644</td>
#       <td id="T_a05ef_row3_col2" class="data row3 col2" >50.3832</td>
#       <td id="T_a05ef_row3_col3" class="data row3 col3" >0.9364</td>
#       <td id="T_a05ef_row3_col4" class="data row3 col4" >0.2299</td>
#       <td id="T_a05ef_row3_col5" class="data row3 col5" >0.3852</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a05ef_row4_col0" class="data row4 col0" >28.7245</td>
#       <td id="T_a05ef_row4_col1" class="data row4 col1" >1580.6671</td>
#       <td id="T_a05ef_row4_col2" class="data row4 col2" >39.7576</td>
#       <td id="T_a05ef_row4_col3" class="data row4 col3" >0.9643</td>
#       <td id="T_a05ef_row4_col4" class="data row4 col4" >0.1013</td>
#       <td id="T_a05ef_row4_col5" class="data row4 col5" >0.0930</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a05ef_row5_col0" class="data row5 col0" >37.2655</td>
#       <td id="T_a05ef_row5_col1" class="data row5 col1" >2212.3250</td>
#       <td id="T_a05ef_row5_col2" class="data row5 col2" >47.0354</td>
#       <td id="T_a05ef_row5_col3" class="data row5 col3" >0.9474</td>
#       <td id="T_a05ef_row5_col4" class="data row5 col4" >0.1170</td>
#       <td id="T_a05ef_row5_col5" class="data row5 col5" >0.1228</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a05ef_row6_col0" class="data row6 col0" >21.4191</td>
#       <td id="T_a05ef_row6_col1" class="data row6 col1" >961.7394</td>
#       <td id="T_a05ef_row6_col2" class="data row6 col2" >31.0119</td>
#       <td id="T_a05ef_row6_col3" class="data row6 col3" >0.9707</td>
#       <td id="T_a05ef_row6_col4" class="data row6 col4" >0.0782</td>
#       <td id="T_a05ef_row6_col5" class="data row6 col5" >0.0928</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a05ef_row7_col0" class="data row7 col0" >13.5109</td>
#       <td id="T_a05ef_row7_col1" class="data row7 col1" >693.2726</td>
#       <td id="T_a05ef_row7_col2" class="data row7 col2" >26.3301</td>
#       <td id="T_a05ef_row7_col3" class="data row7 col3" >0.9830</td>
#       <td id="T_a05ef_row7_col4" class="data row7 col4" >0.3016</td>
#       <td id="T_a05ef_row7_col5" class="data row7 col5" >0.0748</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a05ef_row8_col0" class="data row8 col0" >0.5236</td>
#       <td id="T_a05ef_row8_col1" class="data row8 col1" >1.5081</td>
#       <td id="T_a05ef_row8_col2" class="data row8 col2" >1.2280</td>
#       <td id="T_a05ef_row8_col3" class="data row8 col3" >0.0000</td>
#       <td id="T_a05ef_row8_col4" class="data row8 col4" >0.5781</td>
#       <td id="T_a05ef_row8_col5" class="data row8 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a05ef_row9_col0" class="data row9 col0" >18.5891</td>
#       <td id="T_a05ef_row9_col1" class="data row9 col1" >661.6182</td>
#       <td id="T_a05ef_row9_col2" class="data row9 col2" >25.7219</td>
#       <td id="T_a05ef_row9_col3" class="data row9 col3" >0.9795</td>
#       <td id="T_a05ef_row9_col4" class="data row9 col4" >0.0685</td>
#       <td id="T_a05ef_row9_col5" class="data row9 col5" >0.0693</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a05ef_row10_col0" class="data row10 col0" >38.4036</td>
#       <td id="T_a05ef_row10_col1" class="data row10 col1" >3153.7172</td>
#       <td id="T_a05ef_row10_col2" class="data row10 col2" >56.1580</td>
#       <td id="T_a05ef_row10_col3" class="data row10 col3" >0.9214</td>
#       <td id="T_a05ef_row10_col4" class="data row10 col4" >0.1620</td>
#       <td id="T_a05ef_row10_col5" class="data row10 col5" >0.1831</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a05ef_row11_col0" class="data row11 col0" >33.4991</td>
#       <td id="T_a05ef_row11_col1" class="data row11 col1" >2623.1440</td>
#       <td id="T_a05ef_row11_col2" class="data row11 col2" >51.2166</td>
#       <td id="T_a05ef_row11_col3" class="data row11 col3" >0.9228</td>
#       <td id="T_a05ef_row11_col4" class="data row11 col4" >0.1379</td>
#       <td id="T_a05ef_row11_col5" class="data row11 col5" >0.1306</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a05ef_row12_col0" class="data row12 col0" >21.7918</td>
#       <td id="T_a05ef_row12_col1" class="data row12 col1" >1183.1098</td>
#       <td id="T_a05ef_row12_col2" class="data row12 col2" >34.3964</td>
#       <td id="T_a05ef_row12_col3" class="data row12 col3" >0.9644</td>
#       <td id="T_a05ef_row12_col4" class="data row12 col4" >0.0939</td>
#       <td id="T_a05ef_row12_col5" class="data row12 col5" >0.0871</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a05ef_row13_col0" class="data row13 col0" >14.2127</td>
#       <td id="T_a05ef_row13_col1" class="data row13 col1" >568.9963</td>
#       <td id="T_a05ef_row13_col2" class="data row13 col2" >23.8536</td>
#       <td id="T_a05ef_row13_col3" class="data row13 col3" >0.9835</td>
#       <td id="T_a05ef_row13_col4" class="data row13 col4" >0.0858</td>
#       <td id="T_a05ef_row13_col5" class="data row13 col5" >0.0973</td>
#     </tr>
#     <tr>
#       <th id="T_a05ef_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a05ef_row14_col0" class="data row14 col0" >54.1518
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# #### 차트

# %%
plot_model(cat)

# %%
plot_model(cat, plot='error')

# %%
plot_model(cat, plot='vc')

# %%
#석식계 인덱스 조정
pred_esb_l=pred_esb_l.set_index('년')
pred_esb_l=pred_esb_l.reset_index()
submission_esb['석식계'] = pred_esb_l['Label']

submission_esb
# Out:
#             일자          중식계         석식계
# 0   2021-01-27   923.573983  303.650724
# 1   2021-01-28   853.696894  325.733734
# 2   2021-01-29   569.062825  210.934242
# 3   2021-02-01  1054.533159  377.047639
# 4   2021-02-02   916.343217  344.350344
# 5   2021-02-03   883.556199  319.757603
# 6   2021-02-04   850.089673  354.749872
# 7   2021-02-05   614.957184  252.541770
# 8   2021-02-08  1046.841787  418.342197
# 9   2021-02-09   931.733294  364.070752
# 10  2021-02-10   692.378522  240.011360
# 11  2021-02-15  1039.141063  493.892344
# 12  2021-02-16   935.953924  441.613079
# 13  2021-02-17   923.280480  302.234284
# 14  2021-02-18   766.931452  398.041489
# 15  2021-02-19   593.920655  235.747401
# 16  2021-02-22  1005.471289  441.697174
# 17  2021-02-23   863.944475  418.932494
# 18  2021-02-24   753.247780  294.910318
# 19  2021-02-25   731.748186  388.199052
# 20  2021-02-26   527.102787  220.103724
# 21  2021-03-02   979.536993  458.664884
# 22  2021-03-03   884.095368  331.846832
# 23  2021-03-04   820.588991  399.433337
# 24  2021-03-05   611.036220  263.712400
# 25  2021-03-08  1031.194366  479.478510
# 26  2021-03-09   940.603347  485.470497
# 27  2021-03-10   880.815751  302.945061
# 28  2021-03-11   844.090434  394.013579
# 29  2021-03-12   616.678853  231.899843
# 30  2021-03-15  1045.019290  472.011722
# 31  2021-03-16   910.046252  413.917951
# 32  2021-03-17   928.461244  301.602113
# 33  2021-03-18   826.760506  377.246982
# 34  2021-03-19   585.283235  219.076847
# 35  2021-03-22  1025.384084  454.488280
# 36  2021-03-23   901.223116  436.157265
# 37  2021-03-24   801.785010  296.916685
# 38  2021-03-25   709.107910  330.509040
# 39  2021-03-26   541.099408  219.784276
# 40  2021-03-29  1017.082347  441.015517
# 41  2021-03-30   894.980171  417.563800
# 42  2021-03-31   847.138781  288.728422
# 43  2021-04-01   717.135821  337.680648
# 44  2021-04-02   544.654250  231.668873
# 45  2021-04-05  1028.422416  433.909833
# 46  2021-04-06   899.302217  418.237151
# 47  2021-04-07   836.045007  312.988274
# 48  2021-04-08   761.205829  377.848369
# 49  2021-04-09   588.130265  268.049428
